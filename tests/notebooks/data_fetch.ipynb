# %% [markdown]
# # Data Fetching Demo
#
# Demonstrates fetching historical data from Polygon.io and IBKR,
# then converting to NautilusTrader format for backtesting.

# %%
import sys, os
sys.path.append(os.path.abspath("../.."))

import pandas as pd
from trader import DataHandler, make_fx_pair, SIM
from trader.data.catalog import dataframe_to_nautilus_bars
from nautilus_trader.model.data import BarType

# %% [markdown]
# ## Polygon.io Data Fetch

# %%
from historical_data_services.polygon_data_fetch import fetch_polygon_bars

# Fetch bars from Polygon and save to parquet (returns output path)
# Requires POLYGON_API_KEY environment variable
# out = fetch_polygon_bars("USDJPY", "2024-01-01", "2025-01-01", market="fx")
# print(out)
print("Polygon fetch ready (uncomment to run)")

# %% [markdown]
# ## IBKR Data Fetch

# %%
from historical_data_services.ibkr_data_fetch import fetch_ibkr_bars, fetch_ibkr_bars_range_fx

# Fetch USDJPY 1-day bars from IBKR
# Requires IB TWS/Gateway running
# df = await fetch_ibkr_bars("USDJPY", bar_size="1 day", duration="1 Y")
print("IBKR fetch ready (uncomment to run)")

# %% [markdown]
# ## Convert to NautilusTrader Format

# %%
# Load existing parquet and convert to Nautilus bars
handler = DataHandler()

# Example: load a local parquet file
# df = handler.load_parquet("data/USDJPY_1min_2024-01-01_2025-10-01.parquet")
# instrument = make_fx_pair("USDJPY", SIM, lot_size=100_000)
# bar_type = BarType.from_str(f"{instrument.id}-1-MINUTE-MID-EXTERNAL")
# bars = dataframe_to_nautilus_bars(df, bar_type)
# print(f"Converted {len(bars)} bars")

print("Conversion ready (uncomment to run with your data)")
