# %% [markdown]
# # TradeRunner Streaming Demo (Two Gotobi Entries)
# Simulate live streaming from the USDJPY parquet into Backtrader using two `GotobiBT` legs with different entry/exit times and sizes. Trade sizes are in contracts and multiplied by the broker contract size (see `config/contracts.json`).

# %% [markdown]
# ## Prerequisites
# - `backtrader`
# - `pandas`
# - Repo root on `PYTHONPATH`
# - Contract sizes config at `config/contracts.json` (defaults: USDJPY/EURUSD/GBPUSD = 100,000)

# %%
import sys
from pathlib import Path

REPO_ROOT = Path(r"C:\Users\justi\OneDrive\Trading")  # <-- adjust if your path differs
sys.path.insert(0, str(REPO_ROOT))

# %%
from backend import (
    RunnerConfig,
    StrategySpec,
    TradeRunnerBuilder,
    DataHandler,
    DataStreamer,
)
from strategies.gotobi_bt import GotobiBT
from pprint import pprint

# %%
# Load sample data
DATA_PATH = Path(r"C:\Users\justi\OneDrive\Trading\data\usdjpy_1min_2024-01-01_2025-10-01.parquet")
if not DATA_PATH.exists():
    raise FileNotFoundError(f"Sample parquet not found: {DATA_PATH}")

handler = DataHandler()
df = handler.load_parquet(DATA_PATH)
print(df.head())
print("Rows:", len(df))
# Out:
#                               open     high      low    close  volume
# datetime
# 2024-01-01 00:32:00+00:00  141.020  141.020  141.020  141.020       1
# 2024-01-01 00:33:00+00:00  140.952  140.952  140.952  140.952       1
# 2024-01-01 06:45:00+00:00  140.962  141.025  140.962  141.025       5
# 2024-01-01 06:46:00+00:00  141.026  141.026  141.025  141.025       2
# 2024-01-01 17:04:00+00:00  141.399  141.400  140.995  141.110       6
# Rows: 644043

# %%
# Set up streaming source (use a subset to keep the demo quick)
streamer = DataStreamer()
bar_queue = streamer.subscribe()
stream_df = df
print("Streaming bars:", len(stream_df))
# Out:
# Streaming bars: 644043

# %%
# Custom no-settlement days (add your dates here)
custom_nosettle = set()

# %%
# Build TradeRunner with two Gotobi legs (sizes are contract counts; contract_size pulled from config/contracts.json)
spec = StrategySpec(
    symbol="USDJPY",
    strategy=GotobiBT,  # base strategy ref
    strategies=[
        (
            GotobiBT,
            {
                "entry_time": "09:00:00",
                "exit_time": "09:55:00",
                "use_holidays": True,
                "notrade_days": custom_nosettle,
                "gotobi_days": (5, 10, 15, 20, 25, 30),
                "trade_size": 1,  # 1 contract -> multiplied by 100,000 lot if config present
            },
        ),
        (
            GotobiBT,
            {
                "entry_time": "10:00:00",
                "exit_time": "10:45:00",
                "use_holidays": True,
                "notrade_days": custom_nosettle,
                "gotobi_days": (5, 10, 15, 20, 25, 30),
                "trade_size": -1,  # short 1 contract
            },
        ),
    ],
    data=bar_queue,  # queue will be wrapped by StreamingOHLCVFeed inside TradeRunner
    name="gotobi-usdjpy-stream",
    cash=1000,
    commission=0.00001,
    leverage=500,
)

config = RunnerConfig(
    mode="live",
    base_currency="USD",
    invert_fx_to_base=True,
    preload=False,
    contracts_config_path="config/contracts.json",
    default_contract_size_fx=100000,
)

pool = TradeRunnerBuilder().build([spec], config=config)
runner = pool.runners[0]

# Start strategy thread then stream bars in this thread
thread = runner.start_async()
streamer.from_dataframe(stream_df, delay_sec=0.0)  # push bars then send sentinel None on close
thread.join()
# Out:
# [2024-01-05 09:01:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px
10:01:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=143.833
# [2025-05-05 10:46:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=143.903
# [2025-05-15 09:01:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=145.796
# [2025-05-15 09:56:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=145.869
# [2025-05-15 10:01:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=145.945
# [2025-05-15 10:46:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=145.907
# [2025-05-20 09:01:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=144.486
# [2025-05-20 09:56:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=144.53
# [2025-05-20 10:01:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=144.472
# [2025-05-20 10:46:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=144.536
# [2025-05-30 09:01:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=144.023
# [2025-05-30 09:56:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=144.048
# [2025-05-30 10:01:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=143.985
# [2025-05-30 10:46:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=143.916
# [2025-06-05 09:01:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=143.242
# [2025-06-05 09:56:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=143.194
# [2025-06-05 10:01:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=143.209
# [2025-06-05 10:46:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=143.073
# [2025-06-10 09:01:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=144.664
# [2025-06-10 09:56:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=144.75
# [2025-06-10 10:01:00] ORDER Margin gotobi-usdjpy-stream
# [2025-06-20 09:01:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=145.34
# [2025-06-20 09:56:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=145.337
# [2025-06-20 10:01:00] ORDER Margin gotobi-usdjpy-stream
# [2025-06-25 09:01:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=145.475
# [2025-06-25 09:56:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=145.658
# [2025-06-25 10:01:00] ORDER Margin gotobi-usdjpy-stream
# [2025-06-30 09:01:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=144.114
# [2025-06-30 09:56:00] ORDER Margin gotobi-usdjpy-stream
# [2025-06-30 10:01:00] ORDER Margin gotobi-usdjpy-stream
# [2025-06-30 10:46:00] ORDER Margin gotobi-usdjpy-stream
# [2025-07-01 09:56:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=142.945
# [2025-07-10 09:01:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=146.363
# [2025-07-10 09:56:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=146.192
# [2025-07-10 10:01:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=146.175
# [2025-07-10 10:46:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=146.113
# [2025-07-15 09:01:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=147.677
# [2025-07-15 09:56:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=147.722
# [2025-07-15 10:01:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=147.713
# [2025-07-15 10:46:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=147.757
# [2025-07-25 09:01:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=147.754
# [2025-07-25 09:56:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=147.846
# [2025-07-25 10:01:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=147.901
# [2025-07-25 10:46:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=147.779
# [2025-07-30 09:01:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=147.971
# [2025-07-30 09:56:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=147.999
# [2025-07-30 10:01:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=148.02
# [2025-07-30 10:46:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=148.198
# [2025-08-05 09:01:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=147.574
# [2025-08-05 09:56:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=147.627
# [2025-08-05 10:01:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=147.663
# [2025-08-05 10:46:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=147.599
# [2025-08-15 09:01:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=146.837
# [2025-08-15 09:56:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=146.888
# [2025-08-15 10:01:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=146.875
# [2025-08-15 10:46:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=146.926
# [2025-08-20 09:01:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=147.571
# [2025-08-20 09:56:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=147.476
# [2025-08-20 10:01:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=147.457
# [2025-08-20 10:46:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=147.418
# [2025-08-25 09:01:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=147.259
# [2025-08-25 09:56:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=147.361
# [2025-08-25 10:01:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=147.342
# [2025-08-25 10:46:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=147.412
# [2025-09-05 09:01:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=148.157
# [2025-09-05 09:56:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=148.173
# [2025-09-05 10:01:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=148.171
# [2025-09-05 10:46:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=148.108
# [2025-09-10 09:01:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=147.519
# [2025-09-10 09:56:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=147.4
# [2025-09-10 10:01:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=147.416
# [2025-09-10 10:46:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=147.463
# [2025-09-15 09:01:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=147.419
# [2025-09-15 09:56:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=147.38
# [2025-09-15 10:01:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=147.351
# [2025-09-15 10:46:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=147.34
# [2025-09-25 09:01:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=148.745
# [2025-09-25 09:56:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=148.778
# [2025-09-25 10:01:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=148.784
# [2025-09-25 10:46:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=148.737
# [2025-09-30 09:01:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=147.861
# [2025-09-30 09:56:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=147.974
# [2025-09-30 10:01:00] ORDER BUY gotobi-usdjpy-stream size=100000 px=147.955
# [2025-09-30 10:46:00] ORDER SELL gotobi-usdjpy-stream size=-100000 px=147.992

# %%
# Inspect results
cerebro = runner.cerebro
broker_value = cerebro.broker.getvalue() if cerebro else None
print("Final broker value:", broker_value)

# Access strategy/analyzer objects if needed
pprint(runner.results)
# Out:
# Final broker value: 106036.1300000024
# [<strategies.gotobi_bt.GotobiBT object at 0x00000146D145EF90>,
#  <strategies.gotobi_bt.GotobiBT object at 0x00000146D1349610>]
